# %%
from PIL import Image

obrazek = Image.open("/content/top2.jpeg")
sirka, vyska = obrazek.size

x = 0
while x < sirka:
    y = 0
    while y < vyska:
        r, g, b = obrazek.getpixel((x, y))

        # Convert to grayscale (average of RGB values)
        grayscale = int((r + g + b) / 3)

        # Set pixel to grayscale value
        obrazek.putpixel((x, y), (grayscale, grayscale, grayscale))

        y += 1
    x += 1

display(obrazek)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x674>
